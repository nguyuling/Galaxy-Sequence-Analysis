# %% [markdown]
# ### **Connect to Galaxy API**

# %%
import os
from bioblend.galaxy import GalaxyInstance
from dotenv import load_dotenv

# connect to the galaxy server (api key store .env file)
load_dotenv()
galaxy_url = "https://usegalaxy.org"
api_key = os.getenv("API_KEY")
gi = GalaxyInstance(url=galaxy_url, key=api_key)

# create history and save its id globally for the notebook
history_name = "Metagenomics_Analysis"
history = gi.histories.create_history(name="history_name")
history_id = history["id"]
print(f"Connected. Active History: '{history_name}' (ID: {history_id})")

# helper function to find tool ids quickly
def get_tool_id(tool_name):
    tools = gi.tools.get_tools(name=tool_name)
    if tools:
        print(f"✓ Found '{tools[0]['name']}': {tools[0]['id']}")
        return tools[0]["id"]
    print(f"✗ Tool '{tool_name}' not found.")
    return None
# Out:
# Connected. Active History: 'Metagenomics_Analysis' (ID: bbd44e69cb8906b5eabcb07bee3a4338)

# %%
fastqc = get_tool_id("FastQC")
kraken2 = get_tool_id("Kraken2")
# Out:
# ✓ Found 'FastQC': toolshed.g2.bx.psu.edu/repos/devteam/fastqc/fastqc/0.63
# ✓ Found 'Kraken2': toolshed.g2.bx.psu.edu/repos/iuc/kraken2/kraken2/2.1.3+galaxy1

# %% [markdown]
# ### **Upload Reads**

# %%
# read 1
r1_upload = gi.tools.upload_file_from_url(
    path=None,
    file_name="https://zenodo.org/record/4081603/files/gut_R1.fastq.gz",
    history_id=history_id,
    file_type="fastqsanger.gz",
)

# read 2
r2_upload = gi.tools.upload_file_from_url(
    path=None,
    file_name="https://zenodo.org/record/4081603/files/gut_R2.fastq.gz",
    history_id=history_id,
    file_type="fastqsanger.gz",
)

r1_id = r1_upload["outputs"][0]["id"]
r2_id = r2_upload["outputs"][0]["id"]

print(f"R1 Dataset ID: {r1_id}")
print(f"R2 Dataset ID: {r2_id}")
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[10], line 6
#       2 r1_payload = {
#       3     "files_0|url_paste": "https://zenodo.org/record/4081603/files/gut_R1.fastq.gz",
#       4     "files_0|type": "fastqsanger.gz",
#       5 }
# ----> 6 r1_job = gi.tools.run_tool(
#       7     history_id=history_id,
#       8     tool_id="upload1",
#       9     tool_inputs=r1_payload
#
# File ~/Galaxy/.venv/lib/python3.13/site-packages/bioblend/galaxy/tools/__init__.py:494, in ToolClient.run_tool(self, history_id, tool_id, tool_inputs, input_format, data_manager_mode, credentials_context)
#     491 if credentials_context is not None:
#     492     payload["credentials_context"] = credentials_context
# --> 494 return self._post(payload)
#
# File ~/Galaxy/.venv/lib/python3.13/site-packages/bioblend/galaxy/client.py:196, in Client._post(self, payload, id, deleted, contents, url, files_attached)
#     194 if not url:
#     195     url = self._make_url(module_id=id, deleted=deleted, contents=contents)
# --> 196 return self.gi.make_post_request(url, payload=payload, files_attached=files_attached)
#
# File ~/Galaxy/.venv/lib/python3.13/site-packages/bioblend/galaxyclient.py:206, in GalaxyClient.make_post_request(self, url, payload, params, files_attached)
#     200         raise ConnectionError(
#     201             f"Request was successful, but cannot decode the response content: {e}",
#     202             body=r.content,
#     203             status_code=r.status_code,
#     204         )
#     205 # @see self.body for HTTP response body
# --> 206 raise ConnectionError(
#     207     f"Unexpected HTTP status code: {r.status_code}",
#     208     body=r.text,
#     209     status_code=r.status_code,
#     210 )
#
# ConnectionError: Unexpected HTTP status code: 403: {"err_msg": "Action requires account activation.", "err_code": 403007}
